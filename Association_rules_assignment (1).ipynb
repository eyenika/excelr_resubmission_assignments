# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_excel("Online retail.xlsx", header=None)
df
# Out:
#                                                       0
# 0     shrimp,almonds,avocado,vegetables mix,green gr...
# 1                                burgers,meatballs,eggs
# 2                                               chutney
# 3                                        turkey,avocado
# 4     mineral water,milk,energy bar,whole wheat rice...
# ...                                                 ...
# 7496                      butter,light mayo,fresh bread
# 7497  burgers,frozen vegetables,eggs,french fries,ma...
# 7498                                            chicken
# 7499                                 escalope,green tea
# 7500    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7501 rows x 1 columns]

# %%
#preprocessing
transactions = df[0].dropna().apply(lambda row: [item.strip() for item in row.split(',')]).tolist()
transactions
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
basket_df = pd.DataFrame(te_array, columns=te.columns_)

# %%
te
# Out:
# TransactionEncoder()

# %%
te_array
# Out:
# array([[ True,  True, False, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
basket_df
# Out:
#       almonds  antioxydant juice  asparagus  avocado  babies food  bacon  \
# 0        True               True      False     True        False  False
# 1       False              False      False    False        False  False
# 2       False              False      False    False        False  False
# 3       False              False      False     True        False  False
# 4       False              False      False    False        False  False
# ...       ...                ...        ...      ...          ...    ...
# 7496    False              False      False    False        False  False
# 7497    False              False      False    False        False  False
# 7498    False              False      False    False        False  False
# 7499    False              False      False    False        False  False
# 7500    False              False      False    False        False  False
#
#       barbecue sauce  black tea  blueberries  body spray  ...  turkey  \
# ...

# %%
#frequent items using apropi algorithm
frequent_itemsets = apriori(basket_df, min_support=0.03, use_colnames=True)

# %%
frequent_itemsets
# Out:
#      support                            itemsets
# 0   0.033329                           (avocado)
# 1   0.033729                          (brownies)
# 2   0.087188                           (burgers)
# 3   0.030129                            (butter)
# 4   0.081056                              (cake)
# 5   0.046794                         (champagne)
# 6   0.059992                           (chicken)
# 7   0.163845                         (chocolate)
# 8   0.080389                           (cookies)
# 9   0.051060                       (cooking oil)
# 10  0.031862                    (cottage cheese)
# 11  0.179709                              (eggs)
# 12  0.079323                          (escalope)
# 13  0.170911                      (french fries)
# 14  0.043061                       (fresh bread)
# 15  0.063325                   (frozen smoothie)
# 16  0.095321                 (frozen vegetables)
# 17  0.052393                     (grated cheese)
# ...

# %%
#association rules generation
from mlxtend.frequent_patterns import association_rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
rules
# Out:
#             antecedents          consequents  antecedent support  \
# 0                (eggs)          (chocolate)            0.179709
# 1           (chocolate)               (eggs)            0.163845
# 2        (french fries)          (chocolate)            0.170911
# 3           (chocolate)       (french fries)            0.163845
# 4                (milk)          (chocolate)            0.129583
# 5           (chocolate)               (milk)            0.163845
# 6       (mineral water)          (chocolate)            0.238368
# 7           (chocolate)      (mineral water)            0.163845
# 8           (spaghetti)          (chocolate)            0.174110
# 9           (chocolate)          (spaghetti)            0.163845
# 10       (french fries)               (eggs)            0.170911
# 11               (eggs)       (french fries)            0.179709
# 12               (eggs)               (milk)            0.179709
# ...

# %%
print(frequent_itemsets)
# Out:
#      support                            itemsets
# 0   0.033329                           (avocado)
# 1   0.033729                          (brownies)
# 2   0.087188                           (burgers)
# 3   0.030129                            (butter)
# 4   0.081056                              (cake)
# 5   0.046794                         (champagne)
# 6   0.059992                           (chicken)
# 7   0.163845                         (chocolate)
# 8   0.080389                           (cookies)
# 9   0.051060                       (cooking oil)
# 10  0.031862                    (cottage cheese)
# 11  0.179709                              (eggs)
# 12  0.079323                          (escalope)
# 13  0.170911                      (french fries)
# 14  0.043061                       (fresh bread)
# 15  0.063325                   (frozen smoothie)
# 16  0.095321                 (frozen vegetables)
# 17  0.052393                     (grated cheese)
# ...

# %%
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#             antecedents          consequents   support  confidence      lift
# 0                (eggs)          (chocolate)  0.033196    0.184718  1.127397
# 1           (chocolate)               (eggs)  0.033196    0.202604  1.127397
# 2        (french fries)          (chocolate)  0.034395    0.201248  1.228284
# 3           (chocolate)       (french fries)  0.034395    0.209927  1.228284
# 4                (milk)          (chocolate)  0.032129    0.247942  1.513276
# 5           (chocolate)               (milk)  0.032129    0.196094  1.513276
# 6       (mineral water)          (chocolate)  0.052660    0.220917  1.348332
# 7           (chocolate)      (mineral water)  0.052660    0.321400  1.348332
# 8           (spaghetti)          (chocolate)  0.039195    0.225115  1.373952
# 9           (chocolate)          (spaghetti)  0.039195    0.239219  1.373952
# 10       (french fries)               (eggs)  0.036395    0.212949  1.184961
# ...

# %%
#What is lift and why is it important in association rules?
->Lift will tell how  more likely two items are bought together when compared to just by chance.
->if the value is more than 1 then we can say that the relationship is more strong.

# %%
#What is support and confidence? How do you calculate them?
->support shows how often the group of items are seen together in the dataset.
->confidence shows how often an item is bought together when other item is already bought together.

# %%
#What are some limitations or challenges of Association Rule Mining?
->does not show cause-and-effect, just patterns.
->can create too many rules, which can be overwhelming
